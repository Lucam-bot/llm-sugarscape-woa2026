# %%
"""
Analisi Risultati Batch Sugarscape
====================================
Legge i CSV prodotti da batch_simulation.py e genera:
  1. Tabelle riassuntive
  2. Grafici di sopravvivenza, combattimenti, zucchero
  3. Curve di sopravvivenza nel tempo per ogni configurazione
  4. Heatmap grid_size x avg_sugar

Uso:
  - Modifica BATCH_FOLDER con il path della cartella batch
  - Esegui lo script o le celle nel notebook
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from pathlib import Path
import json
import warnings
warnings.filterwarnings('ignore')

# ============================================================
# ========  CONFIGURAZIONE  ==================================
# ============================================================

# Edit this path to point to a specific batch folder under ./results/simulation_data
BATCH_FOLDER = Path("../results/simulation_data")

# %%
analyze_batch()
